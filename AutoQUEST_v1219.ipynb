# %%
import os
import psycopg2
from openai import OpenAI
import json
import time
import re

# Configure OpenAI API
llm = OpenAI(
    api_key="sk-16a90ba86cfcxxxxxx",  # Ensure to secure your API key
    base_url="https://api.deepseek.com"
)

# PostgreSQL Database Connection Parameters
DATABASE = {
    'database': os.getenv('DB_NAME', 'maude'),
    'user': os.getenv('DB_USER', 'postgres'),
    'password': os.getenv('DB_PASSWORD', 'xxxxxx'),
    #'host': os.getenv('DB_HOST', '192.168.8.167'),
    'host': os.getenv('DB_HOST', 'server.natappfree.cc'),
    #'port': os.getenv('DB_PORT', '5432')
    'port': os.getenv('DB_PORT', '33755')
}
SCHEMA = 'maude'

def generate_response(prompt):
    """
    Generate a response from OpenAI based on the provided prompt.
    """
    try:
        response = llm.chat.completions.create(
            model="deepseek-chat",
            messages=[
                {"role": "user", "content": prompt},
            ]
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Error calling OpenAI API: {e}")
        return None

def read_prompt_file(file_path):
    """
    Read the content of the prompt file.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
        return content
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def connect_database():
    """
    Establish a connection to the PostgreSQL database.
    """
    try:
        conn = psycopg2.connect(**DATABASE)
        cursor = conn.cursor()
        print("Successfully connected to the database.")
        return conn, cursor
    except Exception as e:
        print(f"Database connection failed: {e}")
        return None, None

def get_table_structure(cursor, table_name):
    """
    Retrieve the structure of a specified table.
    """
    try:
        query = f"""
        SELECT 
            column_name, 
            data_type, 
            character_maximum_length, 
            is_nullable
        FROM 
            information_schema.columns
        WHERE 
            table_schema = '{SCHEMA}' 
            AND table_name = '{table_name}';
        """
        cursor.execute(query)
        columns = cursor.fetchall()
        structure = []
        for col in columns:
            structure.append({
                'column_name': col[0],
                'data_type': col[1],
                'character_max_length': col[2],
                'is_nullable': col[3]
            })
        return structure
    except Exception as e:
        print(f"Error retrieving table structure ({table_name}): {e}")
        return None

def get_sample_data(cursor, table_name, limit=3):
    """
    Retrieve sample data from a specified table.
    """
    try:
        query = f'SELECT * FROM {SCHEMA}."{table_name}" LIMIT {limit};'
        cursor.execute(query)
        rows = cursor.fetchall()
        # Retrieve column names
        col_names = [desc[0] for desc in cursor.description]
        sample_data = [dict(zip(col_names, row)) for row in rows]
        return sample_data
    except Exception as e:
        print(f"Error retrieving sample data ({table_name}): {e}")
        return None

def execute_sql(cursor, sql_query):
    """
    Execute an SQL query and handle the results.
    """
    try:
        cursor.execute(sql_query)
        # If it's a SELECT query, fetch and return the results
        if sql_query.strip().upper().startswith("SELECT"):
            rows = cursor.fetchall()
            col_names = [desc[0] for desc in cursor.description]
            data = [dict(zip(col_names, row)) for row in rows]
            return data, None
        else:
            # For non-SELECT queries, commit the transaction
            cursor.connection.commit()
            return None, None
    except Exception as e:
        return None, str(e)

def extract_table_names(prompt_content):
    """
    Extract real table names from the prompt content.
    Assumes that table names are mentioned in the format `merged table xxx` and replaces them with actual table names.
    For demonstration, uses a predefined mapping.
    """
    # Define a mapping from merged table names to actual table names
    # This should be updated based on actual mappings
    merged_to_real = {
        "Merged_Table_1": "mdrfoi",
        "Merged_Table_2": "patientproblemcode",
        "Merged_Table_3": "some_other_table",  # Replace with actual table names
        # Add all necessary mappings here
    }
    
    # Extract merged table names using regex
    merged_tables = re.findall(r'Merged_Table_\d+', prompt_content)
    
    # Replace merged table names with real table names
    involved_tables = []
    for mt in merged_tables:
        real_table = merged_to_real.get(mt, None)
        if real_table:
            involved_tables.append(real_table)
        else:
            print(f"No real table mapping found for {mt}. Please update the mapping.")
    
    # If no merged tables found, use default involved tables
    if not involved_tables:
        involved_tables = ["mdrfoi", "DEVICE", "deviceproblemcodes", "patient", "patientproblemcode", "foitext", "DISCLAIM"]
    
    return involved_tables

def analyze_data(research_question, data):
    """
    Analyze the data to validate the research question.
    This function can be expanded based on specific analysis requirements.
    For demonstration, it sends the data and research question to OpenAI for analysis.
    """
    if not data:
        print("No data available for analysis.")
        return
    
    # Convert data to JSON string
    data_json = json.dumps(data, ensure_ascii=False)
    
    # Create analysis prompt
    analysis_prompt = (
        f"Based on the following research question and data, analyze the validity and feasibility of the research question.\n\n"
        f"Research Question: {research_question}\n\n"
        f"Data: {data_json}\n\n"
        f"Provide a detailed analysis report:"
    )
    
    # Get analysis report from OpenAI
    analysis_report = generate_response(analysis_prompt)
    if analysis_report:
        print(f"Analysis Report:\n{analysis_report}")
    else:
        print("Failed to generate analysis report.")

# %%
# 1. Read table information from prompt.txt
prompt_file = 'prompt.txt'
prompt_content = read_prompt_file(prompt_file)
if not prompt_content:
    print("Failed to read prompt.txt file.")

# 2. Generate a research question
research_prompt = (
    f"Based on the following MAUDE database table information, propose a meaningful research question.\n\n"
    f"{prompt_content}"
)
research_question = generate_response(research_prompt)
if not research_question:
    print("Failed to generate a research question.")
print(f"Proposed Research Question:\n\n{research_question}\n")
# Out:
# Proposed Research Question:
#
# ### Research Question:
#
# **How do the rates of adverse events and device problems vary across different types of medical devices, and what factors (such as device age, manufacturer, and type of operator) are associated with higher incidence of these events?**
#
# ### Rationale:
#
# This research question is designed to leverage the comprehensive data available in the MAUDE database to explore the following key aspects:
#
# 1. **Variation in Adverse Events by Device Type**: The MAUDE database contains detailed information on various types of medical devices, including their generic names, product codes, and brand names. By analyzing the frequency and types of adverse events reported for different device categories, we can identify which types of devices are more prone to causing harm or malfunctioning.
#
# 2. **Impact of Device Age**: The database includes information on the age of the device at the time of the event. Understanding how the age of a device correlates with the likelihood of an adverse event can provide insights into the longevity and reliability of different medical devices.
#
# 3. **Manufacturer Influence**: The MAUDE database records the manufacturer's name and contact information. By examining the incidence of adverse events across different manufacturers, we can assess whether certain manufacturers have a higher rate of reported issues, which could indicate differences in quality control or manufacturing processes.
#
# 4. **Operator Type**: The database also includes information on the type of person operating the device (e.g., healthcare professional, patient). Investigating how the operator type influences the occurrence of adverse events can help in understanding the role of user proficiency or error in device-related incidents.
#
# ### Potential Analysis:
#
# - **Descriptive Statistics**: Calculate the frequency of adverse events and device problems for each type of medical device.
# - **Correlation Analysis**: Determine the correlation between device age and the likelihood of an adverse event.
# - **Manufacturer Comparison**: Compare the incidence of adverse events across different manufacturers to identify any patterns or outliers.
# - **Operator Analysis**: Analyze the impact of operator type on the occurrence of adverse events to identify any significant differences.
#
# ### Expected Outcomes:
#
# - Identification of high-risk device types and manufacturers.
# - Insights into the relationship between device age and adverse events.
# - Recommendations for improved device design, user training, and regulatory oversight based on the findings.
#
# This research question is both meaningful and feasible given the data available in the MAUDE database, and it has the potential to contribute valuable insights to the field of medical device safety and regulation.

# %%
# 3. Plan execution steps based on the research question
planning_prompt = (
    f"Based on MAUDE Database background information and the following research question, outline specific execution steps, including which tables and fields need to be queried.\n\n\n\n"
    f"Research Question: {research_question}"
)
execution_steps = generate_response(planning_prompt)
if not execution_steps:
    print("Failed to plan execution steps.")
print(f"Planned Execution Steps:\n\n{execution_steps}\n")
# Out:
# 2024-12-08 09:37:22,180 [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Planned Execution Steps:
#
# ### Execution Steps for Research Question Analysis
#
# To address the research question regarding the rates of adverse events and device problems across different types of medical devices and the factors associated with higher incidence, the following steps outline the specific execution plan, including which tables and fields need to be queried from the MAUDE (Manufacturer and User Facility Device Experience) database.
#
# #### Step 1: Data Collection and Initial Query
#
# 1. **Identify Relevant Tables**:
#    - **`device` Table**: Contains information about the device, including device type, manufacturer, and device age.
#    - **`event` Table**: Contains details about the adverse events and device problems reported.
#    - **`manufacturer` Table**: Contains information about the device manufacturers.
#    - **`operator` Table**: Contains information about the type of operator involved in the event.
#
# 2. **Extract Relevant Fields**:
#    - From the **`device` Table**:
#      - `device_id`: Unique identifier for the device.
#      - `generic_name`: Type of medical device.
#      - `product_code`: Code representing the device category.
#      - `manufacturer_name`: Name of the device manufacturer.
#      - `device_age`: Age of the device at the time of the event.
#    - From the **`event` Table**:
#      - `event_id`: Unique identifier for the event.
#      - `event_type`: Type of event (e.g., adverse event, device problem).
#      - `event_date`: Date of the event.
#    - From the **`manufacturer` Table**:
#      - `manufacturer_id`: Unique identifier for the manufacturer.
#      - `manufacturer_name`: Name of the manufacturer.
#    - From the **`operator` Table**:
#      - `operator_id`: Unique identifier for the operator.
#      - `operator_type`: Type of operator (e.g., healthcare professional, patient).
#
# #### Step 2: Data Aggregation and Analysis
#
# 1. **Aggregate Adverse Events by Device Type**:
#    - **Query**: Join the `device` and `event` tables on `device_id`.
#    - **Fields**: `generic_name`, `product_code`, `event_type`.
#    - **Aggregation**: Count the number of adverse events (`event_type = 'adverse event'`) and device problems (`event_type = 'device problem'`) for each device type (`generic_name` or `product_code`).
#
# 2. **Analyze Device Age Impact**:
#    - **Query**: Join the `device` and `event` tables on `device_id`.
#    - **Fields**: `device_age`, `event_type`.
#    - **Aggregation**: Calculate the average number of adverse events and device problems per device age group (e.g., 0-1 year, 1-5 years, 5+ years).
#
# 3. **Compare Incidence by Manufacturer**:
#    - **Query**: Join the `device`, `event`, and `manufacturer` tables on `device_id` and `manufacturer_id`.
#    - **Fields**: `manufacturer_name`, `event_type`.
#    - **Aggregation**: Count the number of adverse events and device problems for each manufacturer.
#
# 4. **Operator Type Analysis**:
#    - **Query**: Join the `device`, `event`, and `operator` tables on `device_id` and `operator_id`.
#    - **Fields**: `operator_type`, `event_type`.
#    - **Aggregation**: Count the number of adverse events and device problems for each operator type.
#
# #### Step 3: Data Visualization and Interpretation
#
# 1. **Descriptive Statistics**:
#    - Use bar charts or pie charts to visualize the frequency of adverse events and device problems by device type, manufacturer, and operator type.
#    - Use line charts to show the correlation between device age and the likelihood of adverse events.
#
# 2. **Correlation Analysis**:
#    - Calculate Pearson or Spearman correlation coefficients to quantify the relationship between device age and adverse events.
#
# 3. **Manufacturer Comparison**:
#    - Rank manufacturers based on the incidence of adverse events and device problems.
#    - Identify any outliers or manufacturers with significantly higher rates of reported issues.
#
# 4. **Operator Analysis**:
#    - Compare the incidence of adverse events and device problems across different operator types.
#    - Identify any significant differences and potential implications for user training and proficiency.
#
# #### Step 4: Reporting and Recommendations
#
# 1. **Summarize Findings**:
#    - Compile the results into a comprehensive report, highlighting the key findings from each analysis.
#    - Identify high-risk device types, manufacturers, and operator types.
#
# 2. **Recommendations**:
#    - Provide recommendations for improved device design, user training, and regulatory oversight based on the identified patterns and correlations.
#    - Suggest targeted inspections or audits for manufacturers with higher rates of adverse events.
#
# 3. **Future Research**:
#    - Identify any gaps in the data or areas for further research, such as the impact of specific device models or the role of environmental factors in device failures.
#
# By following these steps, the research question can be systematically addressed using the MAUDE database, leading to actionable insights and recommendations for enhancing medical device safety and regulation.

# %%
# 4. Connect to the database
conn, cursor = connect_database()
if not conn or not cursor:
    print("database connection failed")

# 5. Identify involved tables by extracting from execution steps
involved_tables = extract_table_names(execution_steps)
print(f"Identified Involved Tables: {involved_tables}\n")
# Out:
# Successfully connected to the database.
# Identified Involved Tables: ['mdrfoi', 'DEVICE', 'deviceproblemcodes', 'patient', 'patientproblemcode', 'foitext', 'DISCLAIM']

# %%
# 6. Check table structures and sample data
table_info = {}
for table in involved_tables:
    # Check if table exists
    structure = get_table_structure(cursor, table)
    if structure is None or not structure:
        print(f"Table '{table}' does not exist or has no columns. Skipping.")
    samples = get_sample_data(cursor, table)
    if samples is None:
        print(f"Unable to retrieve sample data for table: {table}")
    table_info[table] = {
        'structure': structure,
        'samples': samples
    }
    print(f"Table: {table}")
    print(f"Structure: {json.dumps(structure, ensure_ascii=False, indent=2)}")
    print(f"Sample Data: {json.dumps(samples, ensure_ascii=False, indent=2)}\n")

if not table_info:
    print("No valid tables found for analysis. Exiting.")
    cursor.close()
    conn.close()

# Convert table information to JSON for OpenAI processing
table_info_json = json.dumps(table_info, ensure_ascii=False)
# Out:
# Table: mdrfoi
# Structure: [
#   {
#     "column_name": "mdr_report_key",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "event_key",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "report_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "report_source_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_link_flag",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "number_devices_in_event",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "number_patients_in_event",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_received",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "adverse_event_flag",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "product_problem_flag",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_report",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_of_event",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "reprocessed_and_reused_flag",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "reporter_occupation_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "health_professional",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "initial_report_to_fda",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_facility_aware",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "report_date",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "report_to_fda",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_report_to_fda",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "event_location",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_report_to_manufacturer",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_t_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_f_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_l_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_street_1",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_street_2",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_city",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_state",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_zip_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_zip_ext",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_country",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_postal",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_area_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_exchange",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_phone_no",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_extension",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_pcountry",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_pcity",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_contact_plocal",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_street_1",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_street_2",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_city",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_state_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_zip_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_zip_code_ext",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_country_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_g1_postal_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_manufacturer_received",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "device_date_of_manufacture",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "single_use_flag",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "remedial_action",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "previous_use_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "removal_correction_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "event_type",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "distributor_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "distributor_address_1",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "distributor_address_2",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "distributor_city",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "distributor_state_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "distributor_zip_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "distributor_zip_code_ext",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "report_to_manufacturer",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_address_1",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_address_2",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_city",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_state_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_zip_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_zip_code_ext",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_country_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_postal_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "type_of_report",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "source_type",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_added",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_changed",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "reporter_country_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "pma_pmn_num",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "exemption_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "summary_report",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "noe_summarized",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   }
# ]
# Sample Data: [
#   {
#     "mdr_report_key": "18423065",
#     "event_key": null,
#     "report_number": "9610595-2024-00001",
#     "report_source_code": "M",
#     "manufacturer_link_flag": "Y",
#     "number_devices_in_event": null,
#     "number_patients_in_event": null,
#     "date_received": "01/01/2024",
#     "adverse_event_flag": "N",
#     "product_problem_flag": "Y",
#     "date_report": "02/02/2024",
#     "date_of_event": null,
#     "reprocessed_and_reused_flag": "N",
#     "reporter_occupation_code": "100",
#     "health_professional": "Y",
#     "initial_report_to_fda": "N",
#     "date_facility_aware": null,
#     "report_date": null,
#     "report_to_fda": "N",
#     "date_report_to_fda": null,
#     "event_location": null,
#     "date_report_to_manufacturer": null,
#     "manufacturer_contact_t_name": "MR.",
#     "manufacturer_contact_f_name": "TODD",
#     "manufacturer_contact_l_name": "BRILL",
#     "manufacturer_contact_street_1": "800 WEST PARK DRIVE",
#     "manufacturer_contact_street_2": null,
#     "manufacturer_contact_city": "WESTBOROUGH",
#     "manufacturer_contact_state": "MA",
#     "manufacturer_contact_zip_code": "01581",
#     "manufacturer_contact_zip_ext": null,
#     "manufacturer_contact_country": "US",
#     "manufacturer_contact_postal": "01581",
#     "manufacturer_contact_area_code": "508",
#     "manufacturer_contact_exchange": "508",
#     "manufacturer_contact_phone_no": "5082",
#     "manufacturer_contact_extension": null,
#     "manufacturer_contact_pcountry": null,
#     "manufacturer_contact_pcity": "50820776",
#     "manufacturer_contact_plocal": "5082077661",
#     "manufacturer_g1_name": "AIZU OLYMPUS CO., LTD.",
#     "manufacturer_g1_street_1": "3-1-1 NIIDERAKITA",
#     "manufacturer_g1_street_2": null,
#     "manufacturer_g1_city": "AIZUWAKAMATSU-SHI, FUKUSHIMA",
#     "manufacturer_g1_state_code": null,
#     "manufacturer_g1_zip_code": null,
#     "manufacturer_g1_zip_code_ext": null,
#     "manufacturer_g1_country_code": "US",
#     "manufacturer_g1_postal_code": null,
#     "date_manufacturer_received": "01/31/2024",
#     "device_date_of_manufacture": "02/17/2009",
#     "single_use_flag": "N",
#     "remedial_action": null,
#     "previous_use_code": "R",
#     "removal_correction_number": null,
#     "event_type": "M",
#     "distributor_name": null,
#     "distributor_address_1": null,
#     "distributor_address_2": null,
#     "distributor_city": null,
#     "distributor_state_code": null,
#     "distributor_zip_code": null,
#     "distributor_zip_code_ext": null,
#     "report_to_manufacturer": null,
#     "manufacturer_name": null,
#     "manufacturer_address_1": null,
#     "manufacturer_address_2": null,
#     "manufacturer_city": null,
#     "manufacturer_state_code": null,
#     "manufacturer_zip_code": null,
#     "manufacturer_zip_code_ext": null,
#     "manufacturer_country_code": null,
#     "manufacturer_postal_code": null,
#     "type_of_report": "I,F",
#     "source_type": "05,06",
#     "date_added": "01/01/2024",
#     "date_changed": "02/14/2024",
#     "reporter_country_code": "US",
#     "pma_pmn_num": "K100584",
#     "exemption_number": null,
#     "summary_report": "N",
#     "noe_summarized": "1"
#   },
#   {
#     "mdr_report_key": "18423066",
#     "event_key": null,
#     "report_number": "9610595-2024-00002",
#     "report_source_code": "M",
#     "manufacturer_link_flag": "Y",
#     "number_devices_in_event": null,
#     "number_patients_in_event": null,
#     "date_received": "01/01/2024",
#     "adverse_event_flag": "N",
#     "product_problem_flag": "Y",
#     "date_report": "02/26/2024",
#     "date_of_event": "12/15/2023",
#     "reprocessed_and_reused_flag": "N",
#     "reporter_occupation_code": "003",
#     "health_professional": null,
#     "initial_report_to_fda": "N",
#     "date_facility_aware": null,
#     "report_date": null,
#     "report_to_fda": "N",
#     "date_report_to_fda": null,
#     "event_location": null,
#     "date_report_to_manufacturer": null,
#     "manufacturer_contact_t_name": "MR.",
#     "manufacturer_contact_f_name": "TODD",
#     "manufacturer_contact_l_name": "BRILL",
#     "manufacturer_contact_street_1": "800 WEST PARK DRIVE",
#     "manufacturer_contact_street_2": null,
#     "manufacturer_contact_city": "WESTBOROUGH",
#     "manufacturer_contact_state": "MA",
#     "manufacturer_contact_zip_code": "01581",
#     "manufacturer_contact_zip_ext": null,
#     "manufacturer_contact_country": "US",
#     "manufacturer_contact_postal": "01581",
#     "manufacturer_contact_area_code": "508",
#     "manufacturer_contact_exchange": "508",
#     "manufacturer_contact_phone_no": "5082",
#     "manufacturer_contact_extension": null,
#     "manufacturer_contact_pcountry": null,
#     "manufacturer_contact_pcity": "50820776",
#     "manufacturer_contact_plocal": "5082077661",
#     "manufacturer_g1_name": "AIZU OLYMPUS CO., LTD.",
#     "manufacturer_g1_street_1": "3-1-1 NIIDERAKITA",
#     "manufacturer_g1_street_2": null,
#     "manufacturer_g1_city": "AIZUWAKAMATSU-SHI, FUKUSHIMA",
#     "manufacturer_g1_state_code": null,
#     "manufacturer_g1_zip_code": null,
#     "manufacturer_g1_zip_code_ext": null,
#     "manufacturer_g1_country_code": "US",
#     "manufacturer_g1_postal_code": null,
#     "date_manufacturer_received": "02/05/2024",
#     "device_date_of_manufacture": "04/23/2019",
#     "single_use_flag": "N",
#     "remedial_action": null,
#     "previous_use_code": "R",
#     "removal_correction_number": null,
#     "event_type": "M",
#     "distributor_name": null,
#     "distributor_address_1": null,
#     "distributor_address_2": null,
#     "distributor_city": null,
#     "distributor_state_code": null,
#     "distributor_zip_code": null,
#     "distributor_zip_code_ext": null,
#     "report_to_manufacturer": null,
#     "manufacturer_name": null,
#     "manufacturer_address_1": null,
#     "manufacturer_address_2": null,
#     "manufacturer_city": null,
#     "manufacturer_state_code": null,
#     "manufacturer_zip_code": null,
#     "manufacturer_zip_code_ext": null,
#     "manufacturer_country_code": null,
#     "manufacturer_postal_code": null,
#     "type_of_report": "I,F",
#     "source_type": "06,07",
#     "date_added": "01/01/2024",
#     "date_changed": "02/26/2024",
#     "reporter_country_code": "US",
#     "pma_pmn_num": "K201758",
#     "exemption_number": null,
#     "summary_report": "N",
#     "noe_summarized": "1"
#   },
#   {
#     "mdr_report_key": "18423067",
#     "event_key": null,
#     "report_number": "9610595-2024-00003",
#     "report_source_code": "M",
#     "manufacturer_link_flag": "Y",
#     "number_devices_in_event": null,
#     "number_patients_in_event": null,
#     "date_received": "01/01/2024",
#     "adverse_event_flag": "N",
#     "product_problem_flag": "Y",
#     "date_report": "01/23/2024",
#     "date_of_event": "12/08/2023",
#     "reprocessed_and_reused_flag": "N",
#     "reporter_occupation_code": "100",
#     "health_professional": "Y",
#     "initial_report_to_fda": "N",
#     "date_facility_aware": null,
#     "report_date": null,
#     "report_to_fda": "N",
#     "date_report_to_fda": null,
#     "event_location": null,
#     "date_report_to_manufacturer": null,
#     "manufacturer_contact_t_name": "MR.",
#     "manufacturer_contact_f_name": "TODD",
#     "manufacturer_contact_l_name": "BRILL",
#     "manufacturer_contact_street_1": "800 WEST PARK DRIVE",
#     "manufacturer_contact_street_2": null,
#     "manufacturer_contact_city": "WESTBOROUGH",
#     "manufacturer_contact_state": "MA",
#     "manufacturer_contact_zip_code": "01581",
#     "manufacturer_contact_zip_ext": null,
#     "manufacturer_contact_country": "US",
#     "manufacturer_contact_postal": "01581",
#     "manufacturer_contact_area_code": "508",
#     "manufacturer_contact_exchange": "508",
#     "manufacturer_contact_phone_no": "5082",
#     "manufacturer_contact_extension": null,
#     "manufacturer_contact_pcountry": null,
#     "manufacturer_contact_pcity": "50820776",
#     "manufacturer_contact_plocal": "5082077661",
#     "manufacturer_g1_name": "AIZU OLYMPUS CO., LTD.",
#     "manufacturer_g1_street_1": "3-1-1 NIIDERAKITA",
#     "manufacturer_g1_street_2": null,
#     "manufacturer_g1_city": "AIZUWAKAMATSU-SHI, FUKUSHIMA",
#     "manufacturer_g1_state_code": null,
#     "manufacturer_g1_zip_code": null,
#     "manufacturer_g1_zip_code_ext": null,
#     "manufacturer_g1_country_code": "US",
#     "manufacturer_g1_postal_code": null,
#     "date_manufacturer_received": "01/12/2024",
#     "device_date_of_manufacture": "08/26/2016",
#     "single_use_flag": "N",
#     "remedial_action": null,
#     "previous_use_code": "R",
#     "removal_correction_number": null,
#     "event_type": "M",
#     "distributor_name": null,
#     "distributor_address_1": null,
#     "distributor_address_2": null,
#     "distributor_city": null,
#     "distributor_state_code": null,
#     "distributor_zip_code": null,
#     "distributor_zip_code_ext": null,
#     "report_to_manufacturer": null,
#     "manufacturer_name": null,
#     "manufacturer_address_1": null,
#     "manufacturer_address_2": null,
#     "manufacturer_city": null,
#     "manufacturer_state_code": null,
#     "manufacturer_zip_code": null,
#     "manufacturer_zip_code_ext": null,
#     "manufacturer_country_code": null,
#     "manufacturer_postal_code": null,
#     "type_of_report": "I,F",
#     "source_type": "00,01,05,06,07",
#     "date_added": "01/01/2024",
#     "date_changed": "01/23/2024",
#     "reporter_country_code": "CH",
#     "pma_pmn_num": null,
#     "exemption_number": null,
#     "summary_report": "N",
#     "noe_summarized": "1"
#   }
# ]
#
# Table: DEVICE
# Structure: [
#   {
#     "column_name": "mdr_report_key",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "device_event_key",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "implant_flag",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_removed_flag",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "device_sequence_no",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_received",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "brand_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "generic_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_name",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_address_1",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_address_2",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_city",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_state_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_zip_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_zip_code_ext",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_country_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "manufacturer_d_postal_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "device_operator",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "expiration_date_of_device",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "model_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "catalog_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "lot_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "other_id_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "device_availability",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_returned_to_manufacturer",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "device_report_product_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "device_age_text",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "device_evaluated_by_manufactur",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "combination_product_flag",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "udi_di",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "udi_public",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   }
# ]
# Sample Data: [
#   {
#     "mdr_report_key": "18423065",
#     "device_event_key": null,
#     "implant_flag": null,
#     "date_removed_flag": null,
#     "device_sequence_no": "1",
#     "date_received": "2024/01/01",
#     "brand_name": "EVIS EXERA II COLONOVIDEOSCOPE",
#     "generic_name": "COLONOVIDEOSCOPE",
#     "manufacturer_d_name": "AIZU OLYMPUS CO., LTD.",
#     "manufacturer_d_address_1": "3-1-1 NIIDERAKITA",
#     "manufacturer_d_address_2": null,
#     "manufacturer_d_city": "AIZUWAKAMATSU-SHI, FUKUSHIMA",
#     "manufacturer_d_state_code": null,
#     "manufacturer_d_zip_code": "965-8",
#     "manufacturer_d_zip_code_ext": "520",
#     "manufacturer_d_country_code": "JA",
#     "manufacturer_d_postal_code": "965-8520",
#     "device_operator": "0HP",
#     "expiration_date_of_device": null,
#     "model_number": "CF-H180AL",
#     "catalog_number": null,
#     "lot_number": null,
#     "other_id_number": null,
#     "device_availability": "R",
#     "date_returned_to_manufacturer": "2023/12/14",
#     "device_report_product_code": "FDF",
#     "device_age_text": "DA",
#     "device_evaluated_by_manufactur": "Y",
#     "combination_product_flag": "N",
#     "udi_di": "04953170202339",
#     "udi_public": "04953170202339"
#   },
#   {
#     "mdr_report_key": "18423066",
#     "device_event_key": null,
#     "implant_flag": null,
#     "date_removed_flag": null,
#     "device_sequence_no": "1",
#     "date_received": "2024/01/01",
#     "brand_name": "EVIS EXERA III BRONCHOVIDEOSCOPE",
#     "generic_name": "BRONCHOVIDEOSCOPE",
#     "manufacturer_d_name": "AIZU OLYMPUS CO., LTD.",
#     "manufacturer_d_address_1": "3-1-1 NIIDERAKITA",
#     "manufacturer_d_address_2": null,
#     "manufacturer_d_city": "AIZUWAKAMATSU-SHI, FUKUSHIMA",
#     "manufacturer_d_state_code": null,
#     "manufacturer_d_zip_code": "965-8",
#     "manufacturer_d_zip_code_ext": "520",
#     "manufacturer_d_country_code": "JA",
#     "manufacturer_d_postal_code": "965-8520",
#     "device_operator": "0HP",
#     "expiration_date_of_device": null,
#     "model_number": "BF-XP190",
#     "catalog_number": null,
#     "lot_number": null,
#     "other_id_number": null,
#     "device_availability": "R",
#     "date_returned_to_manufacturer": null,
#     "device_report_product_code": "EOQ",
#     "device_age_text": "DA",
#     "device_evaluated_by_manufactur": "Y",
#     "combination_product_flag": "N",
#     "udi_di": "04953170342134",
#     "udi_public": "04953170342134"
#   },
#   {
#     "mdr_report_key": "18423067",
#     "device_event_key": null,
#     "implant_flag": null,
#     "date_removed_flag": null,
#     "device_sequence_no": "1",
#     "date_received": "2024/01/01",
#     "brand_name": "EVIS LUCERA ELITE BRONCHOVIDEOSCOPE",
#     "generic_name": "BRONCHOVIDEOSCOPE",
#     "manufacturer_d_name": "AIZU OLYMPUS CO., LTD.",
#     "manufacturer_d_address_1": "3-1-1 NIIDERAKITA",
#     "manufacturer_d_address_2": null,
#     "manufacturer_d_city": "AIZUWAKAMATSU-SHI, FUKUSHIMA",
#     "manufacturer_d_state_code": null,
#     "manufacturer_d_zip_code": "965-8",
#     "manufacturer_d_zip_code_ext": "520",
#     "manufacturer_d_country_code": "JA",
#     "manufacturer_d_postal_code": "965-8520",
#     "device_operator": "0HP",
#     "expiration_date_of_device": null,
#     "model_number": "BF-Q290",
#     "catalog_number": null,
#     "lot_number": null,
#     "other_id_number": null,
#     "device_availability": "R",
#     "date_returned_to_manufacturer": "2023/12/13",
#     "device_report_product_code": "EOQ",
#     "device_age_text": "DA",
#     "device_evaluated_by_manufactur": "Y",
#     "combination_product_flag": "N",
#     "udi_di": null,
#     "udi_public": null
#   }
# ]
#
# Table: deviceproblemcodes
# Structure: [
#   {
#     "column_name": "ï_1",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "old_to_be_deactivated",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   }
# ]
# Sample Data: [
#   {
#     "ï_1": "1001",
#     "old_to_be_deactivated": "Failure To Run On AC/DC"
#   },
#   {
#     "ï_1": "1002",
#     "old_to_be_deactivated": "Abnormal"
#   },
#   {
#     "ï_1": "1003",
#     "old_to_be_deactivated": "Absorption"
#   }
# ]
#
# Table: patient
# Structure: [
#   {
#     "column_name": "mdr_report_key",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "patient_sequence_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_received",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "sequence_number_treatment",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "sequence_number_outcome",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "patient_age",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "patient_sex",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "patient_weight",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "patient_ethnicity",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "patient_race",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   }
# ]
# Sample Data: [
#   {
#     "mdr_report_key": "1018495",
#     "patient_sequence_number": "1",
#     "date_received": "01/03/2008",
#     "sequence_number_treatment": null,
#     "sequence_number_outcome": null,
#     "patient_age": null,
#     "patient_sex": "Female",
#     "patient_weight": null,
#     "patient_ethnicity": null,
#     "patient_race": null
#   },
#   {
#     "mdr_report_key": "1928445",
#     "patient_sequence_number": "1",
#     "date_received": "12/15/2010",
#     "sequence_number_treatment": "7232CX ICD",
#     "sequence_number_outcome": "H; R",
#     "patient_age": null,
#     "patient_sex": null,
#     "patient_weight": null,
#     "patient_ethnicity": null,
#     "patient_race": null
#   },
#   {
#     "mdr_report_key": "1992699",
#     "patient_sequence_number": "1",
#     "date_received": "02/15/2011",
#     "sequence_number_treatment": "D284VRC ICD",
#     "sequence_number_outcome": "H; R",
#     "patient_age": "39 YR",
#     "patient_sex": "Female",
#     "patient_weight": null,
#     "patient_ethnicity": null,
#     "patient_race": null
#   }
# ]
#
# Table: patientproblemcode
# Structure: [
#   {
#     "column_name": "mdr_report_key",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "patient_sequence_no",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "problem_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_added",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_changed",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   }
# ]
# Sample Data: [
#   {
#     "mdr_report_key": " 619611.0",
#     "patient_sequence_no": " 0.0",
#     "problem_code": "2199",
#     "date_added": "2016/02/05 13:15:36.000",
#     "date_changed": "2016/02/05 13:15:36.000"
#   },
#   {
#     "mdr_report_key": " 2094110.0",
#     "patient_sequence_no": " 1.0",
#     "problem_code": "2104",
#     "date_added": "2017/01/12 15:57:46.000",
#     "date_changed": "2017/01/12 15:57:46.000"
#   },
#   {
#     "mdr_report_key": " 2094110.0",
#     "patient_sequence_no": " 1.0",
#     "problem_code": "2348",
#     "date_added": "2017/01/12 15:57:46.000",
#     "date_changed": "2017/01/12 15:57:46.000"
#   }
# ]
#
# Table: foitext
# Structure: [
#   {
#     "column_name": "mdr_report_key",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "NO"
#   },
#   {
#     "column_name": "mdr_text_key",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "NO"
#   },
#   {
#     "column_name": "text_type_code",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "patient_sequence_number",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "date_report",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   },
#   {
#     "column_name": "foi_text",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   }
# ]
# Sample Data: [
#   {
#     "mdr_report_key": "18423218",
#     "mdr_text_key": "331765296",
#     "text_type_code": "D",
#     "patient_sequence_number": "0",
#     "date_report": null,
#     "foi_text": "IT WAS REPORTED THAT THE IPG WOULD NOT HOLD A CHARGE AND IT REQUIRED THE PATIENT MORE EFFORT TO CHARGE THE DEVICE. THE PATIENT UNDERWENT AN IPG REPLACEMENT PROCEDURE AND WAS DOING WELL POSTOPERATIVELY. THE EXPLANTED DEVICE WAS KEPT BY THE MEDICAL FACILITY."
#   },
#   {
#     "mdr_report_key": "18434081",
#     "mdr_text_key": "331765325",
#     "text_type_code": "N",
#     "patient_sequence_number": "0",
#     "date_report": null,
#     "foi_text": "(B)(4)."
#   },
#   {
#     "mdr_report_key": "18434081",
#     "mdr_text_key": "331765326",
#     "text_type_code": "D",
#     "patient_sequence_number": "0",
#     "date_report": null,
#     "foi_text": "IT WAS REPORTED THAT SIGNAL LOSS OVER ONE HOUR OCCURRED. A REVIEW OF THE SHARE LOGS WAS PERFORMED AND A LOSS OF CONNECTION WAS NOT FOUND WITHIN THE INVESTIGATION WINDOW. THE ALLEGATION WAS NOT CONFIRMED. THE PROBABLE CAUSE COULD NOT BE DETERMINED. NO INJURY OR MEDICAL INTERVENTION WAS REPORTED."
#   }
# ]
#
# Table: DISCLAIM
# Structure: [
#   {
#     "column_name": "lifeprod_life_products_inc_the_filing_of_this_report_is_not_an_",
#     "data_type": "text",
#     "character_max_length": null,
#     "is_nullable": "YES"
#   }
# ]
# Sample Data: [
#   {
#     "lifeprod_life_products_inc_the_filing_of_this_report_is_not_an_": "TRAVLABO        TRAVENOL LAB INC                                  THE FILING OF THIS REPORT IS NOT AN ADMISSION THAT THE DESCRIBED INCIDENT IS A REPORTABLE EVENT. THE INFORMATION IS BEING PROVIDED TO ADVISE THE FDA OF OUR RECEIPT OF A POSSIBLE COMPLAINT AND THE ASSOCIATED CIRCUMSTANCES BUT DOES NOT ADMIT LIABILITY OR THAT THE INFORMATION ACTUALLY FALLS UNDER THE MANDATORY REPORTING REQUIREMENTS.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          *"
#   },
#   {
#     "lifeprod_life_products_inc_the_filing_of_this_report_is_not_an_": "AMES            AMES DIV                                          THIS REPORT IS FILED PURSUANT TO 21 CFR, PART 803, AND DOES NOT CONSTITUTE AN ADMISSION THAT THE DEVICE IN QUESTION MALFUNCTIONED OR CONTRIBUTED TO A DEATH OR SERIOUS INJURY. IN 21 CFR, PART 803.24(F), IT IS STATED THAT ANY RELEASE BY THE FDA OF A REPORT SUBMITTED UNDER THIS SECTION DOES NOT NECESSARILY REFLECT A CONCLUSION BY THE FDA \"THAT THE REPORT OR INFORMATION CONSTITUTES AN ADMISSION THAT THE DEVICE CAUSED OR CONTRIBUTED TO A DEATH OR SERIOUS INJURY OR MALFUNCTIONED.\"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       *"
#   },
#   {
#     "lifeprod_life_products_inc_the_filing_of_this_report_is_not_an_": "MEDRAD          MEDRAD INC                                        THIS REPORT IS BASED ON INFORMATION SUPPLIED TO US WITHOUT OUR INDEPENDENT VERIFICATION AS TO ITS ACCURACY, COMPLETENESS OR CAUSAL RELATIONSHIP TO- THE PRODUCT.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      *"
#   }
# ]

# %%
sql_prompt = (
    f"Based on the following execution steps and table information, generate SQL queries to answer the research question.\n\n"
    #f"MAUDE general Information: {prompt_content}\n\n"
    f"Research Question: {research_question}\n\n"
    f"Execution Steps: {execution_steps}\n\n"
    f"Table Information: {table_info_json}\n\n"
    f"Ensure that table names are formatted as maude.\"TABLENAME\" and use the correct column names as per the table structures.\n\n"
    f"**Constraint**: Please ensure that the SQL query does not return more than 10 hits by limited 10.\n\n"
    f"**Additional Requirement**: Each generated SQL statement should be self-contained and independent, meaning they should not rely on the execution of other SQL statements. If there are dependencies between queries, combine them into a single, cohesive SQL statement."
)
sql_query_full = generate_response(sql_prompt)
if not sql_query_full:
    print("Failed to generate SQL query.")
    cursor.close()
    conn.close()
print(f"Generated SQL Query:\n\n{sql_query_full}\n")
# Out:
# 2024-12-08 09:38:47,258 [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Generated SQL Query:
#
# ### SQL Queries to Address the Research Question
#
# #### 1. Aggregate Adverse Events by Device Type
# ```sql
# SELECT
#     d.generic_name,
#     d.product_code,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.generic_name, d.product_code
# LIMIT 10;
# ```
#
# #### 2. Analyze Device Age Impact
# ```sql
# SELECT
#     d.device_age_text,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.device_age_text
# LIMIT 10;
# ```
#
# #### 3. Compare Incidence by Manufacturer
# ```sql
# SELECT
#     d.manufacturer_d_name,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.manufacturer_d_name
# LIMIT 10;
# ```
#
# #### 4. Operator Type Analysis
# ```sql
# SELECT
#     d.device_operator,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.device_operator
# LIMIT 10;
# ```
#
# ### Explanation of SQL Queries
#
# 1. **Aggregate Adverse Events by Device Type**:
#    - This query joins the `DEVICE` and `mdrfoi` tables on `mdr_report_key` to aggregate adverse events and device problems by `generic_name` and `product_code`.
#
# 2. **Analyze Device Age Impact**:
#    - This query joins the `DEVICE` and `mdrfoi` tables to count adverse events and device problems grouped by `device_age_text`.
#
# 3. **Compare Incidence by Manufacturer**:
#    - This query joins the `DEVICE` and `mdrfoi` tables to count adverse events and device problems grouped by `manufacturer_d_name`.
#
# 4. **Operator Type Analysis**:
#    - This query joins the `DEVICE` and `mdrfoi` tables to count adverse events and device problems grouped by `device_operator`.
#
# Each query is self-contained and independent, ensuring that it does not rely on the execution of other SQL statements. The `LIMIT 10` constraint ensures that each query returns no more than 10 hits.

# %%
import re
pattern = r'```sql\n(.*?)```'
matches = re.findall(pattern, sql_query_full, re.DOTALL)
if matches: # Extract the SQL query and remove any leading/trailing whitespace 
    sql_queries = [match.strip() for match in matches]
    print("Extracted SQL Query:\n")
    # 遍历 sql_queries 数组并逐一打印每个 SQL 查询
    for idx, query in enumerate(sql_queries, start=1):
        print(f"--- SQL Query {idx} ---")
        print(query)
        print("\n")  # 添加空行以增加可读性
else: 
    print("No SQL code block found in sql_query_full.")
# Out:
# Extracted SQL Query:
#
# --- SQL Query 1 ---
# SELECT
#     d.generic_name,
#     d.product_code,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.generic_name, d.product_code
# LIMIT 10;
#
#
# --- SQL Query 2 ---
# SELECT
#     d.device_age_text,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.device_age_text
# LIMIT 10;
#
#
# --- SQL Query 3 ---
# SELECT
#     d.manufacturer_d_name,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.manufacturer_d_name
# LIMIT 10;
#
#
# --- SQL Query 4 ---
# SELECT
#     d.device_operator,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.device_operator
# LIMIT 10;

# %%
import re
import time
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(message)s',
    handlers=[
        logging.StreamHandler()
    ]
)

# Connect to the database
conn, cursor = connect_database()
if not conn or not cursor:
    logging.error("Database connection failed.")
else:
    logging.info("Successfully connected to the database.")

# Initialize an empty list to collect all data
dataall = []

try:
    # Iterate through each SQL query in the sql_queries list
    for idx, sql_query in enumerate(sql_queries, start=1):
        logging.info(f"Executing SQL Query {idx}/{len(sql_queries)}:\n{sql_query}\n")
        
        attempt = 0
        while attempt < max_retries:
            data, error = execute_sql(cursor, sql_query)
            
            if error:
                logging.error(f"SQL Execution Error on Query {idx}: {error}\n")
                
                # Check if the error is related to transaction state
                if "current transaction is aborted" in error.lower():
                    try:
                        cursor.execute("ROLLBACK;")
                        conn.commit()
                        logging.info("Rolled back the aborted transaction.")
                    except Exception as rollback_error:
                        logging.error(f"Failed to rollback transaction: {rollback_error}")
                        break  # Cannot recover from this state
                    attempt += 1
                    continue  # Retry the same query after rollback
                    
                # Prepare the correction prompt for OpenAI
                correction_prompt = (
                    f"The following SQL query resulted in an error. Please correct it based on the error message.\n\n"
                    f"Error Message: {error}\n\n"
                    f"Original SQL Query:\n{sql_query}\n\n"
                    f"Table Information: {table_info_json}\n\n"
                    f"Provide the corrected SQL query."
                )
                
                # Request OpenAI to correct the SQL query
                corrected_sql = generate_response(correction_prompt)
                
                if not corrected_sql:
                    logging.warning("Failed to correct SQL query. Skipping to the next query.\n")
                    break  # Exit the retry loop and proceed to the next query
                
                logging.info(f"Corrected SQL Query {idx}:\n\n{corrected_sql}\n")
                
                # Extract the SQL query from the corrected response
                pattern = r'```sql\n(.*?)```'
                matches = re.findall(pattern, corrected_sql, re.DOTALL)
                if matches:
                    # Update only the current query with the corrected version
                    corrected_query = matches[0].strip()
                    logging.info(f"Updating Query {idx} with corrected SQL.")
                    sql_query = corrected_query
                else:
                    logging.warning("No SQL code block found in corrected SQL. Skipping to the next query.")
                    break  # Skip to the next query if no correction found
                
                attempt += 1
                time.sleep(1)  # Brief pause before retrying
            else:
                logging.info(f"SQL Query {idx} executed successfully.\n")
                # Append the retrieved data to dataall
                if data:
                    dataall.extend(data)
                    logging.info(f"Retrieved {len(data)} records from Query {idx}.\n")
                else:
                    logging.info(f"No data returned from Query {idx}.\n")
                break  # Exit the retry loop and proceed to the next query
        
        # After max_retries, check if the last attempt resulted in an error
        if error and attempt == max_retries:
            logging.error(f"Reached maximum retry attempts for Query {idx}. Unable to execute this query.\n")
    
finally:
    # Ensure the database connection is closed properly
    try:
        cursor.close()
        conn.close()
        logging.info("Database connection closed.")
    except Exception as close_error:
        logging.error(f"Error closing database connection: {close_error}")

# Optional: Display the aggregated data
logging.info(f"Total records retrieved from all queries: {len(dataall)}")
# Out:
# 2024-12-08 09:47:32,000 [INFO] Successfully connected to the database.
# 2024-12-08 09:47:32,002 [INFO] Executing SQL Query 1/4:
# SELECT
#     d.generic_name,
#     d.product_code,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.generic_name, d.product_code
# LIMIT 10;
# Successfully connected to the database.
# 2024-12-08 09:47:32,275 [ERROR] SQL Execution Error on Query 1: column d.product_code does not exist
# LINE 3:     d.product_code,
#             ^
#
#
# 2024-12-08 09:47:32,683 [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# 2024-12-08 09:47:44,231 [INFO] Corrected SQL Query 1:
#
# The error message indicates that the column `d.product_code` does not exist in the `maude."DEVICE"` table. Based on the provided table information, it appears that the correct column name should be `device_report_product_code`.
#
# Here is the corrected SQL query:
#
# ```sql
# SELECT
#     d.generic_name,
#     d.device_report_product_code,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.generic_name, d.device_report_product_code
# LIMIT 10;
# ```
#
# This query uses the correct column name `device_report_product_code` instead of `product_code`.
#
# 2024-12-08 09:47:44,232 [INFO] Updating Query 1 with corrected SQL.
# 2024-12-08 09:47:45,400 [ERROR] SQL Execution Error on Query 1: current transaction is aborted, commands ignored until end of transaction block
#
#
# 2024-12-08 09:47:45,673 [INFO] Rolled back the aborted transaction.
# 2024-12-08 09:47:46,478 [INFO] SQL Query 1 executed successfully.
#
# 2024-12-08 09:47:46,479 [INFO] Retrieved 10 records from Query 1.
#
# 2024-12-08 09:47:46,479 [INFO] Executing SQL Query 2/4:
# SELECT
#     d.device_age_text,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.device_age_text
# LIMIT 10;
#
# 2024-12-08 09:47:46,964 [INFO] SQL Query 2 executed successfully.
#
# 2024-12-08 09:47:46,965 [INFO] Retrieved 10 records from Query 2.
#
# 2024-12-08 09:47:46,966 [INFO] Executing SQL Query 3/4:
# SELECT
#     d.manufacturer_d_name,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.manufacturer_d_name
# LIMIT 10;
#
# 2024-12-08 09:47:47,429 [INFO] SQL Query 3 executed successfully.
#
# 2024-12-08 09:47:47,429 [INFO] Retrieved 10 records from Query 3.
#
# 2024-12-08 09:47:47,430 [INFO] Executing SQL Query 4/4:
# SELECT
#     d.device_operator,
#     COUNT(CASE WHEN m.adverse_event_flag = 'Y' THEN 1 END) AS adverse_event_count,
#     COUNT(CASE WHEN m.product_problem_flag = 'Y' THEN 1 END) AS device_problem_count
# FROM
#     maude."DEVICE" d
# JOIN
#     maude."mdrfoi" m ON d.mdr_report_key = m.mdr_report_key
# GROUP BY
#     d.device_operator
# LIMIT 10;
#
# 2024-12-08 09:47:48,118 [INFO] SQL Query 4 executed successfully.
#
# 2024-12-08 09:47:48,119 [INFO] Retrieved 5 records from Query 4.
#
# 2024-12-08 09:47:48,120 [INFO] Database connection closed.
# 2024-12-08 09:47:48,121 [INFO] Total records retrieved from all queries: 35

# %%
# 9. Analyze data to validate the research question
if dataall:
    # Construct the formatted string and assign it to a new variable
    tmp = f"{sql_query_full}\n\nSQL Execution Outcome:\n{dataall}"

    analyze_data(research_question, data)
# Out:
# 2024-12-08 09:48:07,588 [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# Analysis Report:
# ### Analysis Report: Validity and Feasibility of the Research Question
#
# #### 1. **Research Question Overview**
#
# **Research Question:**
# "How do the rates of adverse events and device problems vary across different types of medical devices, and what factors (such as device age, manufacturer, and type of operator) are associated with higher incidence of these events?"
#
# **Rationale:**
# The research question aims to explore variations in adverse events and device problems across different medical devices, considering factors like device age, manufacturer, and operator type. The MAUDE (Manufacturer and User Facility Device Experience) database provides comprehensive data for this analysis.
#
# #### 2. **Data Overview**
#
# The provided data includes:
# - **Device Operator**: Type of person operating the device.
# - **Adverse Event Count**: Number of adverse events reported.
# - **Device Problem Count**: Number of device problems reported.
#
# **Data Sample:**
# ```json
# [
#     {"device_operator": "0", "adverse_event_count": 0, "device_problem_count": 12},
#     {"device_operator": "000", "adverse_event_count": 450, "device_problem_count": 28259},
#     {"device_operator": "0HP", "adverse_event_count": 186977, "device_problem_count": 121482},
#     {"device_operator": "0LP", "adverse_event_count": 38155, "device_problem_count": 178897},
#     {"device_operator": null, "adverse_event_count": 13639, "device_problem_count": 57655}
# ]
# ```
#
# #### 3. **Validity Analysis**
#
# **3.1. Relevance to the Research Question**
# - The data includes counts of adverse events and device problems, which directly address the research question.
# - The inclusion of "device_operator" allows for analysis of the impact of operator type on adverse events, aligning with the research question's focus on operator type.
#
# **3.2. Completeness and Representativeness**
# - The data sample is small and may not be representative of the entire MAUDE database.
# - The presence of null values (e.g., `device_operator: null`) indicates potential data incompleteness, which could affect the validity of the analysis.
#
# **3.3. Clarity and Precision**
# - The data fields are clearly defined, but the meaning of some operator codes (e.g., "0", "000", "0HP", "0LP") is unclear without additional metadata.
# - The research question is precise, but the data's clarity could be improved with more detailed explanations of the operator codes.
#
# #### 4. **Feasibility Analysis**
#
# **4.1. Data Availability**
# - The MAUDE database is comprehensive and contains detailed information on various types of medical devices, including device age, manufacturer, and operator type.
# - The provided data sample is limited but suggests that the necessary data for the research question is available in the MAUDE database.
#
# **4.2. Analytical Techniques**
# - **Descriptive Statistics**: Feasible to calculate the frequency of adverse events and device problems for each device type.
# - **Correlation Analysis**: Feasible to determine the correlation between device age and adverse events.
# - **Manufacturer Comparison**: Feasible to compare adverse event rates across different manufacturers.
# - **Operator Analysis**: Feasible to analyze the impact of operator type on adverse events, though the operator codes need clarification.
#
# **4.3. Resource Requirements**
# - **Data Processing**: Requires tools for data cleaning, transformation, and analysis (e.g., Python, R, SQL).
# - **Statistical Analysis**: Requires statistical software or libraries for correlation analysis and comparison.
# - **Expertise**: Requires expertise in data analysis, medical device safety, and possibly domain-specific knowledge of the MAUDE database.
#
# **4.4. Ethical and Regulatory Considerations**
# - The analysis involves sensitive healthcare data, necessitating compliance with data protection regulations (e.g., HIPAA in the U.S.).
# - Ethical approval may be required if the research involves human subjects or sensitive data.
#
# #### 5. **Conclusion**
#
# **Validity:**
# - The research question is relevant and aligns well with the available data.
# - The data's completeness and clarity could be improved, particularly with respect to operator codes and handling null values.
#
# **Feasibility:**
# - The research question is feasible given the data available in the MAUDE database.
# - The necessary analytical techniques are available, but the project requires careful data processing, statistical analysis, and possibly domain expertise.
#
# **Recommendations:**
# - **Data Clarification**: Obtain additional metadata to clarify the meaning of operator codes and ensure data completeness.
# - **Data Cleaning**: Develop a robust data cleaning process to handle null values and ensure data quality.
# - **Statistical Analysis**: Use appropriate statistical methods to analyze correlations and comparisons, ensuring robustness and validity.
# - **Ethical Compliance**: Ensure compliance with data protection regulations and obtain necessary ethical approvals.
#
# This research question has the potential to provide valuable insights into medical device safety and regulation, but careful attention to data quality and analysis methodology is essential for a valid and feasible study.
